# %%
#install.packages('interactions')
library("ggplot2")
library('interactions')
library("car")
# Out:
# Loading required package: carData

# %%
library('stargazer')
# Out:
# Warning message:
# “package ‘stargazer’ was built under R version 4.0.5”
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
#install.packages('lmerTest')
# Out:
# The downloaded binary packages are in
# 	/var/folders/4k/m0233cfx0fxgl6c4j_9lmk140000gn/T//Rtmpeoh8FO/downloaded_packages

# %%
library(lmerTest)
# Out:
# Loading required package: lme4
#
# Loading required package: Matrix
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
dat<-read.csv('/Users/gouzepeng/OneDrive/王成军音乐/数据/datalyric.csv')

# %%
model = lm(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad, 
                                dat)

# %%
summary(model)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.9779 -0.4190  0.0036  0.4162  6.0177
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.0667916  0.0177576  60.075  < 2e-16 ***
# like_log                         0.9486921  0.0026989 351.505  < 2e-16 ***
# male                             0.1937850  0.0182723  10.605  < 2e-16 ***
# female                           0.0840315  0.0186450   4.507 6.58e-06 ***
# ...

# %%
p<-interact_plot(model, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model2 = lm(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad, 
                                dat)

# %%
summary(model2)
# Out:
# Call:
# lm(formula = musicscore_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.47088 -0.43589  0.02288  0.47766  1.86652
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.9952833  0.0163460 122.065  < 2e-16 ***
# like_log                         0.3282351  0.0024844 132.118  < 2e-16 ***
# male                             0.3136538  0.0168198  18.648  < 2e-16 ***
# ...

# %%
p<-interact_plot(model2, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Music Score",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model3 = lm(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ju+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ju+lyric_topic2_ad, 
                                dat)

# %%
summary(model3)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ju + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ju + lyric_topic2_ad, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.9712 -0.4187  0.0037  0.4168  6.0112
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.0668762  0.0177568  60.083  < 2e-16 ***
# like_log                         0.9488873  0.0026995 351.507  < 2e-16 ***
# male                             0.1961307  0.0182740  10.733  < 2e-16 ***
# female                           0.0861240  0.0186470   4.619 3.87e-06 ***
# ...

# %%
p<-interact_plot(model3, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Music Score",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model4 = lm(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ju+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ju+lyric_topic2_ad, 
                                dat)

# %%
summary(model4)
# Out:
# Call:
# lm(formula = musicscore_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ju + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ju + lyric_topic2_ad, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.47999 -0.43657  0.02324  0.47767  1.90943
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.9963438  0.0163438 122.147  < 2e-16 ***
# like_log                         0.3284263  0.0024847 132.181  < 2e-16 ***
# male                             0.3154037  0.0168198  18.752  < 2e-16 ***
# ...

# %%
p<-interact_plot(model4, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Music Score",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model5 = lm(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic5_ad*ai+lyric_topic5_ad, 
                                dat)

# %%
summary(model5)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic5_ad * ai + lyric_topic5_ad, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.9275 -0.4194  0.0031  0.4181  5.9790
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.1000078  0.0178022  61.790  < 2e-16 ***
# like_log                         0.9497583  0.0027014 351.576  < 2e-16 ***
# male                             0.1882747  0.0182936  10.292  < 2e-16 ***
# female                           0.0863770  0.0186618   4.629 3.69e-06 ***
# ...

# %%
p<-interact_plot(model5, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model6 = lm(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic5_ad*ai+lyric_topic5_ad+lyric_topic5_ad*model_topic5_ad, 
                                dat)

# %%
summary(model6)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic5_ad * ai + lyric_topic5_ad + lyric_topic5_ad *
#     model_topic5_ad, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.9234 -0.4195  0.0031  0.4183  5.9778
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.0926450  0.0179666  60.816  < 2e-16 ***
# like_log                         0.9496955  0.0027014 351.555  < 2e-16 ***
# male                             0.1889904  0.0182944  10.330  < 2e-16 ***
# ...

# %%
p<-interact_plot(model6, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
model7 = lm(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log, 
                                dat)

# %%
model7_a = lm(comment_log~like_log+male+female+
                                model_topic5_ad + model_topic1_ad + model_topic2_ad + model_topic3_ad +
                                model_topic4_ad+
                                posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore+
                                lyric_topic2_ad+albumnum_log, 
                                dat)

# %%
model11 = lm(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log, 
                                dat)

# %%
summary(model11)
# Out:
# Call:
# lm(formula = musicscore_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.39857 -0.43523  0.02353  0.47541  2.02049
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      2.1625116  0.0172484 125.375  < 2e-16 ***
# like_log                         0.3289343  0.0024747 132.920  < 2e-16 ***
# male                             0.3539584  0.0168061  21.061  < 2e-16 ***
# ...

# %%
summary(model11_a)
# Out:
# Call:
# lm(formula = musicscore_log ~ like_log + male + female + model_topic5_ad +
#     model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore + lyric_topic2_ad + albumnum_log,
#     data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.49266 -0.43700  0.02154  0.47987  1.93098
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      2.338e+00  1.262e-02 185.287  < 2e-16 ***
# like_log         2.960e-01  1.199e-03 246.855  < 2e-16 ***
# male             9.444e-02  4.898e-03  19.281  < 2e-16 ***
# female           4.426e-02  4.965e-03   8.914  < 2e-16 ***
# model_topic5_ad  3.594e-02  6.764e-03   5.313 1.08e-07 ***
# model_topic1_ad -1.476e-02  6.485e-03  -2.275 0.022878 *
# model_topic2_ad  6.426e-03  6.783e-03   0.947 0.343480
# model_topic3_ad  3.110e-02  6.524e-03   4.768 1.87e-06 ***
# ...

# %%
model11_a = lm(musicscore_log~like_log+male+female+
                                model_topic5_ad + model_topic1_ad + model_topic2_ad + model_topic3_ad +
                                model_topic4_ad+
                                posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore+
                                lyric_topic2_ad+albumnum_log, 
                                dat)

# %%
model7_c = lmer(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)

# %%
model10 = lmer(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)

# %%
summary(model7_c)
# Out:
# Correlation matrix not shown by default, as p = 30 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: musicscore_log ~ like_log + male + female + like_log * male +
#     like_log * female + model_topic5_ad + model_topic5_ad * male +
#     model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 190655.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9659 -0.6358  0.0302  0.6711  3.7222
#
# Random effects:
# ...

# %%
summary(model10)
# Out:
# Correlation matrix not shown by default, as p = 30 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: musicscore_log ~ like_log + male + female + like_log * male +
#     like_log * female + model_topic5_ad + model_topic5_ad * male +
#     model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 190655.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9659 -0.6358  0.0302  0.6711  3.7222
#
# Random effects:
# ...

# %%
summary(model10_a)
# Out:
# Correlation matrix not shown by default, as p = 22 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML ['lmerMod']
# Formula: musicscore_log ~ like_log + male + female + model_topic5_ad +
#     model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore + lyric_topic2_ad + albumnum_log +
#     (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 191114
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0158 -0.6372  0.0281  0.6732  3.7381
#
# Random effects:
#  Groups        Name        Variance Std.Dev.
#  artist_name_x (Intercept) 0.1548   0.3934
#  Residual                  0.2904   0.5389
# Number of obs: 113111, groups:  artist_name_x, 5573
#
# Fixed effects:
#                   Estimate Std. Error t value
# (Intercept)      2.322e+00  1.852e-02 125.373
# ...

# %%
summary(model7_c)
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: musicscore_log ~ like_log + male + female + like_log * male +
#     like_log * female + model_topic5_ad + model_topic5_ad * male +
#     model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 190755.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9721 -0.6355  0.0309  0.6713  3.7091
#
# Random effects:
#  Groups        Name        Variance Std.Dev.
# ...

# %%
model7_d = lm(musicscore_log~like_log+male+female+
                                model_topic5_ad + model_topic1_ad + model_topic2_ad + model_topic3_ad +
                                model_topic4_ad+
                                posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore+
                                lyric_topic2_ad+albumnum_log, 
                                dat)

# %%
summary(model7_b)
# Out:
# Call:
# lm(formula = musicscore_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.39857 -0.43523  0.02353  0.47541  2.02049
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      2.1625116  0.0172484 125.375  < 2e-16 ***
# like_log                         0.3289343  0.0024747 132.920  < 2e-16 ***
# male                             0.3539584  0.0168061  21.061  < 2e-16 ***
# ...

# %%
summary(model7_a)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + model_topic5_ad +
#     model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore + lyric_topic2_ad + albumnum_log,
#     data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.8760 -0.4180  0.0047  0.4188  5.9309
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      1.3338914  0.0137143  97.263  < 2e-16 ***
# like_log         0.9299373  0.0013032 713.590  < 2e-16 ***
# male             0.1310224  0.0053231  24.614  < 2e-16 ***
# female           0.0065958  0.0053965   1.222 0.221619
# model_topic5_ad  0.0225890  0.0073513   3.073 0.002121 **
# model_topic1_ad  0.0047053  0.0070476   0.668 0.504367
# model_topic2_ad  0.0607723  0.0073717   8.244  < 2e-16 ***
# model_topic3_ad  0.0195346  0.0070906   2.755 0.005870 **
# ...

# %%
summary(model7)
# Out:
# Call:
# lm(formula = comment_log ~ like_log + male + female + like_log *
#     male + like_log * female + model_topic5_ad + model_topic5_ad *
#     male + model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.8660 -0.4170  0.0042  0.4164  5.8649
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      1.2201244  0.0187620  65.032  < 2e-16 ***
# like_log                         0.9492340  0.0026918 352.634  < 2e-16 ***
# male                             0.2301118  0.0182809  12.588  < 2e-16 ***
# ...

# %%
stargazer(model7, type = "html", out="Lm7.html")
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td><em>Dependent variable:</em></td></tr>
# <tr><td></td><td colspan="1" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td>comment_log</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">like_log</td><td>0.949<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.003)</td></tr>
# <tr><td style="text-align:left"></td><td></td></tr>
# <tr><td style="text-align:left">male</td><td>0.230<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.018)</td></tr>
# <tr><td style="text-align:left"></td><td></td></tr>
# <tr><td style="text-align:left">female</td><td>0.113<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.019)</td></tr>
# <tr><td style="text-align:left"></td><td></td></tr>
# ...

# %%
p<-interact_plot(model7, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Autobiographical Transportation", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Negative Emotion",)
p
# Out:
# plot without title

# %%
vif(model7)
# Out:
#                        like_log                            male
#                        4.544542                       18.694583
#                          female                 model_topic5_ad
#                       18.317894                        6.498601
#                 model_topic1_ad                 model_topic2_ad
#                        1.123888                        1.243273
#                 model_topic3_ad                 model_topic4_ad
#                        1.135557                        1.117517
#                        negscore                        posscore
#                        3.777621                        1.478816
#                             hao                              le
#                        1.439800                        1.037992
#                              ai                              nu
#                        1.554098                        1.002438
#                              ju                              er
# ...

# %% [markdown]
# ##### 固定效应

# %%
library(lmerTest)
# Out:
# Loading required package: lme4
#
# Loading required package: Matrix
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
mixed = lmer(comment_log~like_log+male+female+like_log*male+
                 like_log*female+model_topic4+model_topic4*like_log + (1 | artist_name_x), data = dat)
summary(mixed)

# %%
model8 = lmer(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+
                                  (1 | artist_name_x), data = dat)
# Out:
# Warning message:
# “Some predictor variables are on very different scales: consider rescaling”
# Warning message:
# “Some predictor variables are on very different scales: consider rescaling”

# %%
summary(model8)
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: comment_log ~ like_log + male + female + like_log * male + like_log *
#     female + model_topic5_ad + model_topic5_ad * male + model_topic5_ad *
#     female + model_topic1_ad + model_topic2_ad + model_topic3_ad +
#     model_topic4_ad + negscore * model_topic5_ad + posscore +
#     negscore + hao + le + ai + nu + ju + er + jing + mlyric_sen_ai +
#     mlyric_negscore * model_topic5_ad + mlyric_negscore + lyric_topic2_ad *
#     ai + lyric_topic2_ad + lyric_topic2_ad * model_topic5_ad +
#     (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 218755.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.9769  -0.5941   0.0129   0.6028   7.4706
#
# Random effects:
#  Groups        Name        Variance Std.Dev.
# ...

# %%
model9 = lmer(comment_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)
# Out:
# Warning message:
# “Some predictor variables are on very different scales: consider rescaling”
# Warning message:
# “Some predictor variables are on very different scales: consider rescaling”

# %%
model10 = lmer(musicscore_log~like_log+male+female+like_log*male+like_log*female
                                +model_topic5_ad + model_topic5_ad*male + model_topic5_ad*female+
                                model_topic1_ad + model_topic2_ad + model_topic3_ad + model_topic4_ad+
                                negscore*model_topic5_ad+posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore*model_topic5_ad+mlyric_negscore+
                                lyric_topic2_ad*ai+lyric_topic2_ad+lyric_topic2_ad*model_topic5_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)

# %%
summary(model10)
# Out:
# Correlation matrix not shown by default, as p = 30 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: musicscore_log ~ like_log + male + female + like_log * male +
#     like_log * female + model_topic5_ad + model_topic5_ad * male +
#     model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 190655.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9659 -0.6358  0.0302  0.6711  3.7222
#
# Random effects:
# ...

# %%
model10_a = lmer(musicscore_log~like_log+male+female+
                                model_topic5_ad + model_topic1_ad + model_topic2_ad + model_topic3_ad +
                                model_topic4_ad+
                                posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore+
                                lyric_topic2_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)

# %%
class(model10)<- "lmerMod"
class(model10_a)<- "lmerMod"

# %%
summary(model9)
# Out:
# Correlation matrix not shown by default, as p = 30 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: comment_log ~ like_log + male + female + like_log * male + like_log *
#     female + model_topic5_ad + model_topic5_ad * male + model_topic5_ad *
#     female + model_topic1_ad + model_topic2_ad + model_topic3_ad +
#     model_topic4_ad + negscore * model_topic5_ad + posscore +
#     negscore + hao + le + ai + nu + ju + er + jing + mlyric_sen_ai +
#     mlyric_negscore * model_topic5_ad + mlyric_negscore + lyric_topic2_ad *
#     ai + lyric_topic2_ad + lyric_topic2_ad * model_topic5_ad +
#     albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 218715.1
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.9755  -0.5942   0.0126   0.6031   7.4759
#
# Random effects:
# ...

# %%
p9<-interact_plot(model9, pred =model_topic5_ad, modx =  negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Nostalgia of Comments", y.label = "The User Engagement",
                 main.title = "",  legend.main = "Negative Sentiment of Comments",)
p9
# Out:
# plot without title

# %%
pdf("interact_topic_engagement.pdf",width=8,height=6)

p9
dev.off()
# Out:
# pdf
#   2

# %%
model9_a = lmer(comment_log~like_log+male+female+
                                model_topic5_ad + model_topic1_ad + model_topic2_ad + model_topic3_ad +
                                model_topic4_ad+
                                posscore+negscore+hao+le+ai+nu+ju+er+jing+
                                mlyric_sen_ai+mlyric_negscore+
                                lyric_topic2_ad+albumnum_log+
                                  (1 | artist_name_x), data = dat)

# %%
summary(model9_a)
# Out:
# Correlation matrix not shown by default, as p = 22 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# comment_log ~ like_log + male + female + model_topic5_ad + model_topic1_ad +
#     model_topic2_ad + model_topic3_ad + model_topic4_ad + posscore +
#     negscore + hao + le + ai + nu + ju + er + jing + mlyric_sen_ai +
#     mlyric_negscore + lyric_topic2_ad + albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 218999
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.9047  -0.5960   0.0128   0.6038   7.4524
#
# Random effects:
#  Groups        Name        Variance Std.Dev.
#  artist_name_x (Intercept) 0.1319   0.3631
#  Residual                  0.3770   0.6140
# Number of obs: 113111, groups:  artist_name_x, 5573
#
# Fixed effects:
# ...

# %%
class(model10) <- "lmerMod"
class(model10_a)<- "lmerMod"

# %%
stargazer(model7_a,model7,model9_a,model9, title="Results", align=TRUE,type = "html", out="DV_commentnum.html")
# Out:
# <table style="text-align:center"><caption><strong>Results</strong></caption>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable:</em></td></tr>
# <tr><td></td><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4">comment_log</td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em>OLS</em></td><td colspan="2"><em>linear</em></td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em></em></td><td colspan="2"><em>mixed-effects</em></td></tr>
# <tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">like_log</td><td>0.930<sup>***</sup></td><td>0.949<sup>***</sup></td><td>0.898<sup>***</sup></td><td>0.914<sup>***</sup></td></tr>
# ...

# %%
stargazer(model11_a,model11,model10_a,model10, title="Results", align=TRUE,type = "html", out="DV_musicscore.html")
# Out:
# <table style="text-align:center"><caption><strong>Results</strong></caption>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable:</em></td></tr>
# <tr><td></td><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4">musicscore_log</td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em>OLS</em></td><td colspan="2"><em>linear</em></td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em></em></td><td colspan="2"><em>mixed-effects</em></td></tr>
# <tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">like_log</td><td>0.296<sup>***</sup></td><td>0.329<sup>***</sup></td><td>0.285<sup>***</sup></td><td>0.318<sup>***</sup></td></tr>
# ...

# %%
p9_a<-interact_plot(model9, pred =model_topic5_ad, modx =  negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Topic 5", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Negative Score",)
p
# Out:
# plot without title

# %%
p9_a<-interact_plot(model9, pred =model_topic5_ad, modx =  male, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Nostalgia of Comments", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Gender_male",)
p9_a
# Out:
# plot without title

# %%
pdf("interact_topic_gender.pdf",width=8,height=6)

p9_a
dev.off()
# Out:
# pdf
#   2

# %%
p9_b<-interact_plot(model9, pred =model_topic5_ad, modx = lyric_topic2_ad, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Nostalgia of Comments", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Nostalgia of Lyric",)
p9_b
# Out:
# plot without title

# %%
pdf("interact_topic_lyric.pdf",width=8,height=6)

p9_b
dev.off()
# Out:
# pdf
#   2

# %%
p9_c<-interact_plot(model9, pred =ai, modx = lyric_topic2_ad, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Sadness sentiment of Comments", y.label = "Number of Comments",
                 main.title = "",  legend.main = "Nostalgia of Lyric",)
p9_c
# Out:
# plot without title

# %%
pdf("interact_sentiment_lyric.pdf",width=8,height=6)

p9_c
dev.off()
# Out:
# pdf
#   2

# %%
summary(model10)
# Out:
# Correlation matrix not shown by default, as p = 30 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML ['lmerMod']
# Formula: musicscore_log ~ like_log + male + female + like_log * male +
#     like_log * female + model_topic5_ad + model_topic5_ad * male +
#     model_topic5_ad * female + model_topic1_ad + model_topic2_ad +
#     model_topic3_ad + model_topic4_ad + negscore * model_topic5_ad +
#     posscore + negscore + hao + le + ai + nu + ju + er + jing +
#     mlyric_sen_ai + mlyric_negscore * model_topic5_ad + mlyric_negscore +
#     lyric_topic2_ad * ai + lyric_topic2_ad + lyric_topic2_ad *
#     model_topic5_ad + albumnum_log + (1 | artist_name_x)
#    Data: dat
#
# REML criterion at convergence: 190655.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9659 -0.6358  0.0302  0.6711  3.7222
#
# Random effects:
#  Groups        Name        Variance Std.Dev.
# ...

# %%
p10<-interact_plot(model10, pred =model_topic5_ad, modx = negscore, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Nostalgia of Comments", y.label = "Scores of Songs",
                 main.title = "",  legend.main = "Negative Score",)
p10
# Out:
# plot without title

# %%
p10_a<-interact_plot(model10, pred =model_topic5_ad, modx = male, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Nostalgia of Comments", y.label = "Scores of Songs",
                 main.title = "",  legend.main = "Gender_male",)
p10_a
# Out:
# plot without title

# %%
p10_b<-interact_plot(model10, pred =male, modx = like_log, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Gender_male", y.label = "Scores of Songs",
                 main.title = "",  legend.main = "Number of Likes",)
p10_b
# Out:
# plot without title

# %%
p10_c<-interact_plot(model10, pred =female, modx = like_log, 
                  #modx.values = c(0, 0.25, 0.5, 0.75, 1),
                 data = dat, interval = TRUE,int.width = 0.8,
                 x.label = "Gender_female", y.label = "Scores of Songs",
                 main.title = "",  legend.main = "Number of Likes",)
p10_c
# Out:
# plot without title

# %%
pdf("interact_musicscore_topic_commentsenti.pdf",width=8,height=6)

p10
dev.off()
# Out:
# pdf
#   2

# %%
pdf("interact_musicscore_gender_commentnosta.pdf",width=8,height=6)

p10_a
dev.off()
# Out:
# pdf
#   2

# %%
pdf("interact_musicscore_likes_male.pdf",width=8,height=6)

p10_b
dev.off()
# Out:
# pdf
#   2

# %%
pdf("interact_musicscore_likes_female.pdf",width=8,height=6)

p10_c
dev.off()
# Out:
# pdf
#   2
